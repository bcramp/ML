# %% [markdown]
# <a href="https://colab.research.google.com/github/bcramp/ML/blob/main/HW1/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# HW 1
#
# Title: Assignment Analysis
#
# Name: Brennen Cramp
#
# Date: 9/3/2026
#
# ---

# %% [markdown]
# # Analysis
# ---
#
# 1. From a beginning standpoint, the basic steps are to:
#   - 1 - create a GitHub account, create a course repository, and structure that repository.
#   - 2 - use Google Colab to develop the assignments by using the cloud-based runtime feature.
#   - 3 - save your code via Colab to your repository and to verify that there is a link to open in Colab once saved to the HW# folder
#   - 4 - maintain the repository remotely through git add/commit/push/pull commands to ensure the remote is always in sync (source-controlled) with the GitHub version.
#
#   - In summation, key steps for managing files between Google Colab and GitHub include maintaining a rigid structure where each assignments' files will be located (i.e. HW1, HW2, ..., HW#), always keeping your personal repository in sync with changes you have made through Colab (or remotely then uploading that file to Colab to ensure the same file is being changed), and to always save any changes to your structured repo to submit the link at the end of the assignment.
#
# 2. All of the Module 0 notebooks executed successfully in Google Colab on the first try and no syntax or dependencies had to be adjusted. There were no issues with connecting to new runtimes except for notebook 3 where I had to close out my previous runtimes for notebooks 1 and 2 to clear space for additional running instances.
#
# 3. I created my repository by first going to my GitHub home pag (https://github.com/bcramp) and clicking the "+" in the top right ribbon to create my "ML" repo. I then created a folder titled "HW1" via my terminal in VSCode and updated the root-level README and I used git commands to push to my repo. I want to have a structure where the the root folder (ML/) will contain each of the assignments' folder structures and within each folder will be the code required for that assignment and a simple README. If any additional explanations are needed for sturcture, I will provide a README description for that specific folder; i.e. not all folders will have a README with a description if naming of files are basic and simple to follow. For this assignment, each of the corresponding notebooks downloaded from Module 0 (https://github.com/bforoura/ML26/tree/main/Module0_Python) are titled as simply as "Notebook#.ipynb".
#
# 4. The reason for why a strong command of basic Python data structures and syntax is critical before advancing to ML algorithms is due to the fact that ML depends heavily on data manipulation. If developers do not understand data structures for Python, they do not have the adequate tools to analyze and parse data in a computationally efficent manner; nor do they have the tools to aide in formatting and displaying outputs clearly to make understanding this data easier.
